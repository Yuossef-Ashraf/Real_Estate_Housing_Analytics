# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
data = pd.read_csv(r"C:\Users\yuossef\Desktop\holistic\data\Housing.csv")

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
data =data.drop_duplicates()

# %%
data.hist(bins=10 ,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'parking'}>]], dtype=object)

# %%
label_encoders = {}
for column in ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])
data = pd.get_dummies(data, columns=['furnishingstatus'])

# %%
X = data.drop('price', axis=1)
Y = data['price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=20, random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)
Y_predict =model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_predict)
mse=mean_squ

# %%
print("Mean squared error = ", mse)
# Out:
# Mean squared error =  1481674252126.4548

# %%
model =YOLO(r"C:\Users\yuossef\Desktop\holistic\data\Housing.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model =YOLO(r"C:\Users\yuossef\Desktop\holistic\data\Housing.pt")
#
# NameError: name 'YOLO' is not defined

# %%
def predict_house_price(model, features):
    input_data = pd.DataFrame([features], columns=X.columns)
    predict_price = model.predict(input_data)
    return predict_price

# %%
user_input = {}
for column in X.columns:
    user_input[column] = int(input(f"Enter {column}: "))+
predict_price = predict_house_price(model, user_input)
print('Predict Price for house is: ', predict_price[0])
# Out:
#   Cell In[17], line 3
#     user_input[column] = int(input(f"Enter {column}: "))+predict_price = predict_house_price(model, user_input)
#                          ^
# SyntaxError: cannot assign to expression
